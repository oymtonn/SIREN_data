# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# count rates of all muons vs coincidence muons

master = pd.read_csv("final_master_data.csv")
slave = pd.read_csv("final_slave_data.csv")

plt.plot(master["time_stamp"], master["count"])
plt.plot(slave["time_stamp"], slave["count"])
